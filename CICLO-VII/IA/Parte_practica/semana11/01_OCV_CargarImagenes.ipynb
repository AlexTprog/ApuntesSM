# %% [markdown]
# #Pasos previos a la carga de imágenes

# %%
# !wget https://.....
# !unzip -qq nombreArchivo.zip
# %cd ruta

# %%
# %cd ejemploImagenes
# Out:
# [Errno 2] No such file or directory: 'ejemploImagenes'
# /home/alex/Documentos/ApuntesSM/CICLO-VII/IA/Parte_practica/semana11/ejemploImagenes

# %% [markdown]
# #Importación de paquetes necesarios

# %%
from matplotlib import pyplot as plt
import cv2

# %% [markdown]
# Cargar imágenes y mostrarlas en Jupyter Notebook

# %%
#carga la imagen y muestra información sobre esta
imagen = cv2.imread("golden_retriever.jpg")
(alto,ancho,canales) = imagen.shape
print("alto: {} pixeles".format(imagen.shape[0]))
print("ancho: {} pixeles".format(imagen.shape[1]))
print("canales: {}".format(imagen.shape[2]))
# Out:
# alto: 473 pixeles
# ancho: 500 pixeles
# canales: 3

# %%
#convierte la imagen de un formato de color BGR a RGB y lo mostramos
imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
plt.imshow(imagen)
plt.title("Golden")
plt.grid(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Guardar la imagen en formato RGB
cv2.imwrite("nuevaImagen02.jpg",cv2.cvtColor(imagen,cv2.COLOR_RGB2BGR))
# Out:
# True

# %%
# Imágen en su modelo de colores original 
plt.imshow(imagen)

# %%
# Esto se guardaría en un formato BGR
cv2.imwrite("nuevaImagen03.jpg",imagen)
# Out:
# True
