# %%
# %cd ejemploImagenes
# Out:
# /home/alex/Documentos/ApuntesSM/CICLO-VII/IA/Parte_practica/semana11/ejemploImagenes

# %%
from matplotlib import pyplot as plt
import cv2

# %%
def mostrar_imagen(titulo,imagen):
  imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
  plt.imshow(imagen)
  plt.title(titulo)
  plt.grid(False)
  plt.show

# %%
imagen = cv2.imread("labrador.jpg")
mostrar_imagen("Golden Retriever",imagen)

# %%
imagen.shape
# Out:
# (253, 314, 3)

# %%
plt.imshow(imagen)

# %%
#esquina superior izquierda de la imagen
imagen[0,0]
# Out:
# array([251, 246, 247], dtype=uint8)

# %%
print("El pixel 0,0 tiene los colores B=%d G=%d R=%d"%
      (imagen[0,0][0],imagen[0,0][1],imagen[0,0][2]))
# Out:
# El pixel 0,0 tiene los colores B=251 G=246 R=247

# %%
#esquina inferior derecha de la imagen
imagen[252,313]
# Out:
# array([233, 232, 236], dtype=uint8)

# %%
print("El pixel 252,313 tiene los colores B=%d G=%d R=%d"%
      (imagen[252,313][0],imagen[252,313][1],imagen[252,313][2]))
# Out:
# El pixel 252,313 tiene los colores B=233 G=232 R=236

# %%
#Pixel en la nariz del perro
imagen[40,20]
# Out:
# array([32, 35, 40], dtype=uint8)

# %%
#Pixel en la lengua del perro
imagen[60,25]
# Out:
# array([143, 137, 214], dtype=uint8)
