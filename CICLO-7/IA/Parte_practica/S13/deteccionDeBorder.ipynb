# %% [markdown]
# # Detector de bordes de Canny

# %% [markdown]
# ### Importar librerias

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ### Funcion para mostrar imagen

# %%
def mostrar_imagen(titulo,imagen):
    imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
    plt.imshow(imagen)
    plt.title(titulo)
    plt.grid(False)
    plt.show()

# %% [markdown]
# ### Diccionario para los argumentos

# %%
args = {"imagen":"monedas_hp.jpeg"}

# %% [markdown]
# ### Carga la imagen y la muestra

# %%
imagen = cv2.imread(args["imagen"])
mostrar_imagen("Original",imagen)

# %% [markdown]
# ### Deteccion de bordes de canny

# %%
imagen = cv2.imread(args["imagen"])
imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2GRAY)
imagen = cv2.GaussianBlur(imagen,(5,5),0)
mostrar_imagen("Difuminado",imagen)
