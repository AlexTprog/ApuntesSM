# %% [markdown]
# # Detector de bordes de Canny

# %% [markdown]
# ### Importar librerías

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ### Función para mostrar la imagen

# %%
def mostrar_imagen(titulo, imagen):
  imagen = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
  plt.imshow(imagen)
  plt.title(titulo)
  plt.grid(False)
  plt.show()

# %% [markdown]
# ### Diccionario para los argumentos

# %%
args = {"imagen":"lapices.jpeg"}

# %% [markdown]
# ### Carga la imagen y la muestra

# %%
imagen = cv2.imread(args["imagen"])
mostrar_imagen("Original",imagen)

# %% [markdown]
# ### Detección de bordes de Canny

# %% [markdown]
# Carga la imagen, la conviérte a escala de grises y la difumína ligeramente para eliminar los bordes de alta frecuencia que no nos interesan

# %%
imagen = cv2.imread(args["imagen"])
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
imagen = cv2.GaussianBlur(imagen, (5, 5), 0)
mostrar_imagen("Difuminado", imagen)

# %% [markdown]
# Al realizar la detección de bordes de Canny, necesitamos dos valores para la histéresis: umbral1 y umbral2. Cualquier valor de gradiente mayor que el umbral2 se considera un borde. Cualquier valor por debajo del umbral1 no se considera no borde. Los valores entre el umbral1 y el umbral2 se clasifican como borde o no borde en función de cómo están "conectadas" las intensidades. En este caso, cualquier valor de gradiente por debajo de 30 se considera no borde, mientras que cualquier valor por encima de 150 se considera borde.

# %%
canny = cv2.Canny(imagen, 30, 150)
mostrar_imagen("Canny", canny)
